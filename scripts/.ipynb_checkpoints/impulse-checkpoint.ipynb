# %%
import matplotlib.pyplot as plt
import numpy as np
from math import log
import re

t = 0.06

def str_2_norm(line):
    obj = re.search(r'{ (.*) }', line)
    impulse = np.array([float(x) for x in obj.group(1).split(',')])
    return np.linalg.norm(impulse)

with open("impulse.txt") as f:
    lines = f.readlines()
    lines = filter(lambda x: x.startswith("Contact"), lines)
    res = map(lambda x: float(x.split()[-1]), lines)
    impulse_norm = map(str_2_norm, lines)
    impluse_norm = list(impulse_norm)
    res = list(res)
    
fig, ax = plt.subplots()
ax.plot(impluse_norm[:-4])
ax.set(xlabel='linear iteration', ylabel='impulse norm')
# Out:
# [Text(0, 0.5, 'impulse norm'), Text(0.5, 0, 'linear iteration')]
